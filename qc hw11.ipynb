# %% [markdown]
# Sean Kelly
# 10/19/20
# Hw11

# %% [markdown]
# 11.1 C
# ---

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# %%
#f3
circ = QuantumCircuit(3,3) #2 qubits, 2 classical bits
circ.initialize([1,0],0) #initializes 1st qubit to the 0 state
circ.initialize([1,0],1) #initializes 2nd qubit to the 0 state
circ.initialize([1,0],2) #initializes 2nd qubit to the 0 state

circ.h(0)
circ.h(1)

circ.cx(0,2)

circ.measure(0,2)
circ.measure(1,1)
circ.measure(2,0)

circ.draw('mpl')

# %%
sim = Aer.get_backend('qasm_simulator')
res = execute(circ, sim, shots = 10000).result()
plot_histogram(res.get_counts())

# %%
#f5
circ = QuantumCircuit(3,3) #2 qubits, 2 classical bits
circ.initialize([1,0],0) #initializes 1st qubit to the 0 state
circ.initialize([1,0],1) #initializes 2nd qubit to the 0 state
circ.initialize([1,0],2) #initializes 2nd qubit to the 0 state

circ.h(0)
circ.h(1)

circ.cx(1,2)

circ.measure(0,2)
circ.measure(1,1)
circ.measure(2,0)

circ.draw('mpl')

# %%
sim = Aer.get_backend('qasm_simulator')
res = execute(circ, sim, shots = 10000).result()
plot_histogram(res.get_counts())

# %%
#f6
circ = QuantumCircuit(3,3) #2 qubits, 2 classical bits
circ.initialize([1,0],0) #initializes 1st qubit to the 0 state
circ.initialize([1,0],1) #initializes 2nd qubit to the 0 state
circ.initialize([1,0],2) #initializes 2nd qubit to the 0 state

circ.h(0)
circ.h(1)

circ.x(0)
circ.ccx(0,1,2)
circ.x(0)

circ.x(1)
circ.ccx(0,1,2)
circ.x(1)

circ.measure(0,2)
circ.measure(1,1)
circ.measure(2,0)

circ.draw('mpl')

# %%
sim = Aer.get_backend('qasm_simulator')
res = execute(circ, sim, shots = 1000).result()
plot_histogram(res.get_counts())
